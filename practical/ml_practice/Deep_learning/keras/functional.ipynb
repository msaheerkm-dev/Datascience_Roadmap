# %%
from keras.models import Model
from keras.layers import Input,Dense
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
inputs=Input(shape=(100,))
x=Dense(64,activation='relu')(inputs)
output=Dense(10,activation='softmax')(x)
model=Model(inputs=inputs,outputs=output)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         6,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,114 (27.79 KB)
#  Trainable params: 7,114 (27.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
x=np.random.random((1,100))
print(x)
# Out:
# [[0.44106398 0.9573553  0.66288608 0.00908569 0.01059847 0.54290702
#   0.6617236  0.27308933 0.71403472 0.12002332 0.65328792 0.5579697
#   0.60565507 0.06950296 0.50359887 0.00994003 0.20874201 0.73118578
#   0.60472906 0.80329249 0.48414708 0.86770483 0.73516768 0.6821784
#   0.44597997 0.94886028 0.14461202 0.01041726 0.58706769 0.79168037
#   0.77248366 0.18896331 0.26121355 0.80937014 0.45191764 0.81372276
#   0.10307806 0.593311   0.93692353 0.68821494 0.64909655 0.92314172
#   0.53016785 0.91644619 0.96008351 0.24110644 0.0911176  0.32706755
#   0.81816161 0.74487635 0.13591127 0.59824574 0.69374058 0.21561601
#   0.08944658 0.76255043 0.93700914 0.71987203 0.39336734 0.5317792
#   0.27994479 0.46283742 0.33580586 0.62927047 0.51758289 0.44421179
#   0.31108696 0.65310613 0.3591823  0.06449188 0.79930985 0.82447551
#   0.97556921 0.65468352 0.31751367 0.96888016 0.1609977  0.83166311
#   0.68707824 0.63229344 0.70986182 0.09609031 0.74250501 0.74126612
#   0.24012276 0.45090375 0.94628976 0.81126389 0.87129309 0.71089567
#   0.94013742 0.5460949  0.56582537 0.65930539 0.99552381 0.68885988
#   0.53446936 0.48772121 0.10456167 0.24318364]]

# %%
output=model.predict(x)
print(output)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# [[0.09449919 0.09050591 0.13387087 0.04001963 0.06288287 0.07921707
#   0.03358555 0.03239334 0.12695433 0.30607125]]
