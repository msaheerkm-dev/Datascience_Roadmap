# %%
# para - sent

corpus="hello , my name is cristiano ronaldo. I'am here to be the greatest of all time"
from nltk.tokenize import sent_tokenize
documents=sent_tokenize(corpus)
print(documents)
# Out:
# ['hello , my name is cristiano ronaldo.', "I'am here to be the greatest of all time"]

# %%
# para - word
from nltk import word_tokenize
words=word_tokenize(corpus)
print(words)
# Out:
# ['hello', ',', 'my', 'name', 'is', 'cristiano', 'ronaldo', '.', "I'am", 'here', 'to', 'be', 'the', 'greatest', 'of', 'all', 'time']

# %%
# sent - word
for sent in documents:
    print(word_tokenize(sent))
# Out:
# ['hello', ',', 'my', 'name', 'is', 'cristiano', 'ronaldo', '.']
# ["I'am", 'here', 'to', 'be', 'the', 'greatest', 'of', 'all', 'time']

# %%
# punct as seperate word
# use wordpunct_tokenize

# %%
# don't treat period(.) as seperate word
# use TreebankWordTokenizer
# always treat last period(.) as seperate word evenwhen we use TreebankWordTokenizer
