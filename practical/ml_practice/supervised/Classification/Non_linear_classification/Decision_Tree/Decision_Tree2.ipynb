# %%
#  Simple Decision Tree Model using DataFrame

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# 1️ Create a sample dataset (as a DataFrame)
data = {
    'Age': [25, 30, 45, 35, 22, 40, 50, 28, 33, 42],
    'Salary': [50000, 60000, 80000, 75000, 48000, 90000, 110000, 52000, 72000, 95000],
    'Purchased': [0, 0, 1, 1, 0, 1, 1, 0, 1, 1]  # 1 = Yes, 0 = No
}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary  Purchased
# 0   25   50000          0
# 1   30   60000          0
# 2   45   80000          1
# 3   35   75000          1
# 4   22   48000          0
# 5   40   90000          1
# 6   50  110000          1
# 7   28   52000          0
# 8   33   72000          1
# 9   42   95000          1

# %%
import seaborn as sns

sns.pairplot(
    df,
    vars=['Age','Salary'],
    hue='Purchased'
)

# %%
# 2️ Split features and target
X = df[['Age', 'Salary']]
y = df['Purchased']

# %%
for i in X:
    sns.scatterplot(x=X[i],y='Purchased',data=df)
    plt.show()

# %%
X
# Out:
#    Age  Salary
# 0   25   50000
# 1   30   60000
# 2   45   80000
# 3   35   75000
# 4   22   48000
# 5   40   90000
# 6   50  110000
# 7   28   52000
# 8   33   72000
# 9   42   95000

# %%
y
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# 5    1
# 6    1
# 7    0
# 8    1
# 9    1
# Name: Purchased, dtype: int64

# %%
# 3️ Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# 4️ Create and train the Decision Tree model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# 5️ Make predictions
y_pred = model.predict(X_test)

# %%
# 6️ Evaluate accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(model,X_test,y_test)
