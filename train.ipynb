# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.DataFrame(
    {
        'f1':[1,2,3,1,4,5,6,3,2,7],
        'f2':[100,200,350,120,111,123,324,324,211,101],
        'y':[1,0,0,1,1,0,1,0,0,1]
    }
)
print(df)
